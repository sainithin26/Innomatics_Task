# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# movies = pd.read_csv('movies.csv')
# links = pd.read_csv('links.csv')
# ratings = pd.read_csv('ratings.csv')

# %%
movies = pd.read_csv('movies.csv')
links = pd.read_csv('links.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('ratings.csv')

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
len(ratings['userId'].unique())
# Out:
# 610

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
dts = ratings.groupby('movieId')['rating'].count().reset_index()

# %%
dts
# Out:
#       movieId  rating
# 0           1     215
# 1           2     110
# 2           3      52
# 3           4       7
# 4           5      49
# ...       ...     ...
# 9719   193581       1
# 9720   193583       1
# 9721   193585       1
# 9722   193587       1
# 9723   193609       1
#
# [9724 rows x 2 columns]

# %%
dts[dts['rating']==dts['rating'].max()]
# Out:
#      movieId  rating
# 314      356     329

# %%
movies[movies['movieId']==356]
# Out:
#      movieId                title                    genres
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War

# %%
tags = pd.read_csv('tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies[movies['title']=="Matrix, The (1999)"]
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
tags[tags['movieId']==2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
movies[movies['title']=="Terminator 2: Judgment Day (1991)"]
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
ratings['rating'][ratings['movieId']==589].mean()
# Out:
# 3.970982142857143

# %%
movies[movies['title']=="Fight Club (1999)"]
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
rar = ratings['rating'][ratings['movieId']==2959]

# %%
sns.distplot(rar)
# Out:
# <ipython-input-20-10773371417b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(r)
# <Axes: xlabel='rating', ylabel='Density'>

# %%
sn = ratings.groupby('movieId')['rating'].mean().reset_index()

# %%
sn
# Out:
#       movieId    rating
# 0           1  3.920930
# 1           2  3.431818
# 2           3  3.259615
# 3           4  2.357143
# 4           5  3.071429
# ...       ...       ...
# 9719   193581  4.000000
# 9720   193583  3.500000
# 9721   193585  3.500000
# 9722   193587  3.500000
# 9723   193609  4.000000
#
# [9724 rows x 2 columns]

# %%
combined_df = pd.merge(movies, sn, on='movieId', how='inner')

# %%
combined_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres    rating
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                      Adventure|Children|Fantasy  3.431818
# 2                                  Comedy|Romance  3.259615
# 3                            Comedy|Drama|Romance  2.357143
# 4                                          Comedy  3.071429
# ...                                           ...       ...
# 9719              Action|Animation|Comedy|Fantasy  4.000000
# 9720                     Animation|Comedy|Fantasy  3.500000
# 9721                                        Drama  3.500000
# 9722                             Action|Animation  3.500000
# 9723                                       Comedy  4.000000
#
# [9724 rows x 4 columns]

# %%
combined_df[combined_df['rating']==combined_df['rating'].max()]
# Out:
#       movieId                                              title  \
# 48         53                                    Lamerica (1994)
# 87         99               Heidi Fleiss: Hollywood Madam (1995)
# 121       148                   Awfully Big Adventure, An (1995)
# 405       467                             Live Nude Girls (1995)
# 432       495  In the Realm of the Senses (Ai no corrida) (1976)
# ...       ...                                                ...
# 9593   176601                                       Black Mirror
# 9615   179133                              Loving Vincent (2017)
# 9616   179135                              Blue Planet II (2017)
# 9670   184245                            De platte jungle (1978)
# 9693   187717                   Won't You Be My Neighbor? (2018)
#
#                      genres  rating
# 48          Adventure|Drama     5.0
# 87              Documentary     5.0
# 121                   Drama     5.0
# 405                  Comedy     5.0
# 432                   Drama     5.0
# ...                     ...     ...
# 9593     (no genres listed)     5.0
# 9615  Animation|Crime|Drama     5.0
# 9616            Documentary     5.0
# 9670            Documentary     5.0
# 9693            Documentary     5.0
#
# [296 rows x 4 columns]

# %%
len(combined_df['rating'].unique())
# Out:
# 1286

# %%
sn1 = ratings.groupby('movieId')['rating'].count().reset_index()

# %%
sn1
# Out:
#       movieId  rating
# 0           1     215
# 1           2     110
# 2           3      52
# 3           4       7
# 4           5      49
# ...       ...     ...
# 9719   193581       1
# 9720   193583       1
# 9721   193585       1
# 9722   193587       1
# 9723   193609       1
#
# [9724 rows x 2 columns]

# %%
combined_df1 = pd.merge(movies, sn1, on='movieId', how='inner')

# %%
combined_df1
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating
# 0     Adventure|Animation|Children|Comedy|Fantasy     215
# 1                      Adventure|Children|Fantasy     110
# 2                                  Comedy|Romance      52
# 3                            Comedy|Drama|Romance       7
# 4                                          Comedy      49
# ...                                           ...     ...
# 9719              Action|Animation|Comedy|Fantasy       1
# 9720                     Animation|Comedy|Fantasy       1
# 9721                                        Drama       1
# 9722                             Action|Animation       1
# 9723                                       Comedy       1
#
# [9724 rows x 4 columns]

# %%
combined_df1[combined_df1['rating']==combined_df1['rating'].max()]
# Out:
#      movieId                title                    genres  rating
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War     329

# %%
top_5_results = combined_df1.nlargest(5, 'rating')

# %%
top_5_results
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1938     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       rating
# 314      329
# 277      317
# 257      307
# 510      279
# 1938     278

# %%
sub_data = combined_df1[combined_df1['genres'].str.contains('Sci-Fi')]

# %%
sub_data
# Out:
#       movieId                                              title  \
# 23         24                                      Powder (1995)
# 28         29  City of Lost Children, The (Cité des enfants p...
# 31         32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 59         66          Lawnmower Man 2: Beyond Cyberspace (1996)
# 68         76                                   Screamers (1995)
# ...       ...                                                ...
# 9695   188301                        Ant-Man and the Wasp (2018)
# 9704   189547                                Iron Soldier (2010)
# 9706   190183                           The Darkest Minds (2018)
# 9713   191005                                     Gintama (2017)
# 9714   193565                          Gintama: The Movie (2010)
#
#                                       genres  rating
# 23                              Drama|Sci-Fi      28
# 28    Adventure|Drama|Fantasy|Mystery|Sci-Fi      38
# 31                   Mystery|Sci-Fi|Thriller     177
# 59                    Action|Sci-Fi|Thriller       9
# 68                    Action|Sci-Fi|Thriller      15
# ...                                      ...     ...
# 9695  Action|Adventure|Comedy|Fantasy|Sci-Fi       3
# 9704                           Action|Sci-Fi       1
# 9706                         Sci-Fi|Thriller       1
# 9713          Action|Adventure|Comedy|Sci-Fi       1
# 9714          Action|Animation|Comedy|Sci-Fi       1
#
# [980 rows x 4 columns]

# %%
top_5_sci_fi = sub_data.nlargest(5, 'rating')

# %%
top_5_sci_fi
# Out:
#       movieId                                              title  \
# 1938     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 418       480                               Jurassic Park (1993)
# 507       589                  Terminator 2: Judgment Day (1991)
# 897      1196  Star Wars: Episode V - The Empire Strikes Back...
#
#                                 genres  rating
# 1938            Action|Sci-Fi|Thriller     278
# 224            Action|Adventure|Sci-Fi     251
# 418   Action|Adventure|Sci-Fi|Thriller     238
# 507                      Action|Sci-Fi     224
# 897            Action|Adventure|Sci-Fi     211

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.shape
# Out:
# (9742, 3)

# %%
len(links['movieId'].unique())
# Out:
# 9742

# %%
import requests
from bs4 import BeautifulSoup

# %%
sub_data_dts = combined_df1[combined_df1['rating']>50]

# %%
sub_data_dts
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating
# 0     Adventure|Animation|Children|Comedy|Fantasy     215
# 1                      Adventure|Children|Fantasy     110
# 2                                  Comedy|Romance      52
# 5                           Action|Crime|Thriller     102
# 6                                  Comedy|Romance      54
# ...                                           ...     ...
# 8287                           Comedy|Crime|Drama      54
# 8354                                 Comedy|Drama      52
# 8358                                  Sci-Fi|IMAX      73
# 8457                      Action|Adventure|Sci-Fi      59
# 8673               Action|Adventure|Comedy|Sci-Fi      54
#
# [436 rows x 4 columns]

# %%
merged_links = pd.merge(sub_data_dts, links, on='movieId', how='inner')

# %%
merged_links
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  rating   imdbId    tmdbId
# 0    Adventure|Animation|Children|Comedy|Fantasy     215   114709     862.0
# 1                     Adventure|Children|Fantasy     110   113497    8844.0
# 2                                 Comedy|Romance      52   113228   15602.0
# 3                          Action|Crime|Thriller     102   113277     949.0
# 4                                 Comedy|Romance      54   114319   11860.0
# ..                                           ...     ...      ...       ...
# 431                           Comedy|Crime|Drama      54   993846  106646.0
# 432                                 Comedy|Drama      52  2278388  120467.0
# 433                                  Sci-Fi|IMAX      73   816692  157336.0
# 434                      Action|Adventure|Sci-Fi      59  2015381  118340.0
# 435               Action|Adventure|Comedy|Sci-Fi      54  1431045  293660.0
#
# [436 rows x 6 columns]

# %%
def extract_content(imdbId):
    # Send an HTTP request to the URL
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    # URL = f"https://www.imdb.com/title/tt{new_id}/"
    url = f"https://www.imdb.com/title/tt{new_id}/"
    # print(url)

    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }
    response = requests.get(url,headers=request_header)
    # print(response.text)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the content you need from the parsed HTML
        # For example, extract all text within paragraph (p) tags
        content=soup.findAll(attrs={'class':'sc-bde20123-1 cMEQkK'})#extracting only text part
        # remove_subclass_content(content)
        content=content[0].text #replace end line symbol with space
        # title=soup.findAll(attrs={'class':'entry-title'})#extracting title of website
        # title=title[16].text.replace('\n',"  ").replace('/',"")
        text=content #merging title and content text

        return float(text)

#         # Print or return the extracted content
#         for paragraph in paragraphs:
#             print(paragraph.get_text())

    else:
        print(f"Error: Unable to fetch content. Status code {response.status_code}")

# Example usage
# url = "https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/"
# k = extract_content(url)
# print(type(k))
# print(k)

merged_links['imdb_rating'] = merged_links['imdbId'].apply(extract_content)
# nellore = extract_content(merged_links['imdbId'][0])

# %%
merged_links
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  rating   imdbId    tmdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy     215   114709     862.0
# 1                     Adventure|Children|Fantasy     110   113497    8844.0
# 2                                 Comedy|Romance      52   113228   15602.0
# 3                          Action|Crime|Thriller     102   113277     949.0
# 4                                 Comedy|Romance      54   114319   11860.0
# ..                                           ...     ...      ...       ...
# 431                           Comedy|Crime|Drama      54   993846  106646.0
# 432                                 Comedy|Drama      52  2278388  120467.0
# 433                                  Sci-Fi|IMAX      73   816692  157336.0
# 434                      Action|Adventure|Sci-Fi      59  2015381  118340.0
# 435               Action|Adventure|Comedy|Sci-Fi      54  1431045  293660.0
#
#      imdb_rating
# 0            8.3
# 1            7.1
# 2            6.6
# 3            8.3
# 4            6.3
# ..           ...
# 431          8.2
# 432          8.1
# 433          8.7
# 434          8.0
# 435          8.0
#
# [436 rows x 7 columns]

# %%
# prompt: Using dataframe merged_links: get top rating movie

merged_links.sort_values(by='imdb_rating', ascending=False).head(1)
# Out:
#     movieId                             title       genres  rating  imdbId  \
# 53      318  Shawshank Redemption, The (1994)  Crime|Drama     317  111161
#
#     tmdbId  imdb_rating
# 53   278.0          9.3

# %%
merged_sub_data = merged_links[merged_links['genres'].str.contains('Sci-Fi')]

# %%
topp_5_sci_fi = merged_sub_data.nlargest(5, 'imdb_rating')

# %%
topp_5_sci_fi
# Out:
#      movieId                                              title  \
# 424    79132                                   Inception (2010)
# 140     1196  Star Wars: Episode V - The Empire Strikes Back...
# 248     2571                                 Matrix, The (1999)
# 433   109487                                Interstellar (2014)
# 44       260          Star Wars: Episode IV - A New Hope (1977)
#
#                                               genres  rating   imdbId  \
# 424  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX     143  1375666
# 140                          Action|Adventure|Sci-Fi     211    80684
# 248                           Action|Sci-Fi|Thriller     278   133093
# 433                                      Sci-Fi|IMAX      73   816692
# 44                           Action|Adventure|Sci-Fi     251    76759
#
#        tmdbId  imdb_rating
# 424   27205.0          8.8
# 140    1891.0          8.7
# 248     603.0          8.7
# 433  157336.0          8.7
# 44       11.0          8.6
